# %%
# %matplotlib inline
import cv2
from process_image import ProcessImg

# %%
# rover = cv2.imread("Images\\rover.png", cv2.IMREAD_COLOR)
# rover_rgb = ProcessImg(rover)
# rover_bw = ProcessImg(rover, False)

mars = cv2.imread("Images\\mars.png", cv2.IMREAD_COLOR)
# mars_rgb = ProcessImg(mars)
mars_bw = ProcessImg(mars, False)

# %%
mars_bw.display()
