# %%
# %matplotlib inline
import cv2
from process_image import ProcessImg
import os

# %%
path = r"C:/Users/iskha/research/process_img/Images/"
img_paths = {'.jpg','.jpeg', 'png'}

imgs = {}

for i in os.listdir(path):
    name, extension = os.path.splitext(i)
    if not extension.lower() in img_paths:
        continue
    
    img = cv2.imread(path+i,1)
    imgs[name] = ProcessImg(img, makeHist = False)
    
    imgs[name].enhance_all()
    imgs[name].enhance('iagcwd', 'stretch_m1')
    imgs[name].enhance('iagcwd', 'stretch_m2')
    
    imgs[name].display(4)
# Out:
# img not suitable for iagcwd
# img not suitable for iagcwd
# img not suitable for iagcwd
# img not suitable for iagcwd
# C:\Users\iskha\research\process_img\sece.py:43: RuntimeWarning: invalid value encountered in multiply
#   entropy += h * np.log2(h, where = h>0)
# img not suitable for iagcwd
# img not suitable for iagcwd
# img not suitable for iagcwd
# img not suitable for iagcwd
# img not suitable for iagcwd
# img not suitable for iagcwd
# img not suitable for iagcwd
# img not suitable for iagcwd
# img not suitable for iagcwd
# img not suitable for iagcwd
# img not suitable for iagcwd
# img not suitable for iagcwd
# img not suitable for iagcwd
# img not suitable for iagcwd
# img not suitable for iagcwd
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4568/764673912.py in <module>
#      12     imgs[name] = ProcessImg(img, makeHist = False)
#      13
# ---> 14     imgs[name].enhance_all()
#      15     imgs[name].enhance('iagcwd', 'stretch_m1')
#      16     imgs[name].enhance('iagcwd', 'stretch_m2')
#
# ~\research\process_img\process_image.py in enhance_all(self, src)
#     101     def enhance_all(self, src = 'Orig'):
#     102         for key in self.name_to_func:
# --> 103             self.enhance(key, src)
#     104
#     105 #     def apply_contrast_stretch_m1(self, src = "Orig"):
#
# ~\research\process_img\process_image.py in enhance(self, algorithm, src)
#      93             self.img[name] = self.name_to_func[algorithm](img, hist)
#      94         else:
# ---> 95             self.img[name] = self.name_to_func[algorithm](img)
#      96
#      97         self.make_hist(name)
#
# ~\research\process_img\process_image.py in apply_sece_dct(img)
#      25
#      26 def apply_sece_dct(img):
# ---> 27     return sece_dct(img)
#      28
#      29 def apply_sigmoid_stretch(img, a = 12, b = 6):
#
# ~\research\process_img\sece.py in sece_dct(img)
#     128     img_f = np.float32(img_sece)
#     129     img_dct = cv2.dct(img_f)
# --> 130     w = weighting_coefficient(f,H,W)
#     131     img_w = img_dct * w
#     132     img_f = np.float32(img_w)
#
# ~\research\process_img\sece.py in weighting_coefficient(discrete_func, H, W, gamma)
#      92     for k in range(H):
#      93         for l in range(W):
# ---> 94             w[k,l] = (1+temp1*k) * (1+temp2*l)
#      95
#      96     return w
#
# KeyboardInterrupt:

# %%
path = r"C:/Users/iskha/research/process_img/Images/"
img_paths = {'.jpg','.jpeg', 'png'}

imgs = {}

diff = {}

num_imgs = 0

for i in os.listdir(path):
    name, extension = os.path.splitext(i)
    if not extension.lower() in img_paths:
        continue
    
    img = cv2.imread(path+i,1)
    imgs[name] = ProcessImg(img, makeHist = False)
    
    imgs[name].enhance_all()
    imgs[name].enhance('iagcwd', 'stretch_m1')
    imgs[name].enhance('iagcwd', 'stretch_m2')
    
    num_imgs += 1
    
    for key in imgs[name].img:
        if key in diff:
            diff[key] += imgs[name].show_diff(key, display = False, print_avg = False)
        else:
            diff[key] = imgs[name].show_diff(key, display = False, print_avg = False)

for key in diff:
    print(f'avg diff of {key} and Orig is: {diff[key] / num_imgs}')
# Out:
# avg diff of Orig and Orig is: 0.0
# avg diff of iagcwd and Orig is: 18.399334148250702
# avg diff of stretch_m1 and Orig is: 31.18911197155759
# avg diff of stretch_m2 and Orig is: 29.500219570361043
# avg diff of equalize and Orig is: 52.59420651852407
# avg diff of stretch_m1 to iagcwd and Orig is: 36.506913427323035
# avg diff of stretch_m2 to iagcwd and Orig is: 37.75101143249933
# avg diff of sigmoid and Orig is: 33.373586766539546
# avg diff of sece and Orig is: 59.42389348902197
# avg diff of sece_dct and Orig is: 65.2209787725146
